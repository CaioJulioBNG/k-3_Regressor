# %% [markdown]
# ## Importações

# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import (
    RandomForestRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor, 
    AdaBoostRegressor, BaggingRegressor
)
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso, ElasticNet, BayesianRidge
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy.stats import zscore
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Carga de Dados // Tratamento Básico

# %% [markdown]
# ### Carga de Dados

# %%
data_treino = pd.read_csv('/home/caio/github/k-3/data/train.csv')
data_teste = pd.read_csv('/home/caio/github/k-3/data/test.csv')

# %% [markdown]
# ### EDA

# %%
print('-'*50, " Valores NaN em data_treino", "-"*50)
print(data_treino.isnull().sum())
print('-'*50, " Valores NaN em data_teste", "-"*50)
print(data_teste.isnull().sum())
# Out:
# --------------------------------------------------  Valores NaN em data_treino --------------------------------------------------
# id               0
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    0
# windspeed        0
# rainfall         0
# dtype: int64
# --------------------------------------------------  Valores NaN em data_teste --------------------------------------------------
# id               0
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    1
# windspeed        0
# dtype: int64

# %%
print('-'*50, " Outliers em data_treino", "-"*50)
z_scores = data_treino.select_dtypes(include=np.number).apply(zscore)
outliers_z = (abs(z_scores) > 3).sum()
print(outliers_z)

print('-'*50, " Outliers em data_teste", "-"*50)
z_scores = data_teste.select_dtypes(include=np.number).apply(zscore)
outliers_z = (abs(z_scores) > 3).sum()
print(outliers_z)
# Out:
# --------------------------------------------------  Outliers em data_treino --------------------------------------------------
# id                0
# day               0
# pressure          4
# maxtemp           0
# temparature       1
# mintemp           2
# dewpoint         26
# humidity         17
# cloud            31
# sunshine          0
# winddirection     0
# windspeed        15
# rainfall          0
# dtype: int64
# --------------------------------------------------  Outliers em data_teste --------------------------------------------------
# id                0
# day               0
# pressure          1
# maxtemp           1
# temparature       1
# mintemp           2
# dewpoint         10
# humidity          7
# cloud            11
# sunshine          0
# winddirection     0
# windspeed         8
# dtype: int64

# %% [markdown]
# ### Tratamento Básico

# %%
def outliers(data, fator=1.5):
    data_limpa = data.copy()
    
    for col in data_limpa.select_dtypes(include=[np.number]).columns:
        Q1 = data_limpa[col].quantile(0.25)
        Q3 = data_limpa[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - (fator * IQR)
        upper_bound = Q3 + (fator * IQR)
        data_limpa[col] = np.clip(data_limpa[col], lower_bound, upper_bound)
    
    return data_limpa

# %%
# Remoção do valor NaN de winddirection
mediana = data_teste['winddirection'].median()
data_teste['winddirection'] = data_teste['winddirection'].fillna(mediana)

# %% [markdown]
# ### Divisão FEATURE / TARGET

# %%
FEATURE = data_treino.drop(columns=['rainfall']) 
TARGET = data_treino['rainfall']

# %% [markdown]
# ### Divisão Meta-Modelo

# %%
# Treino (50%), Validação para Base (30%), Teste para Meta (20%)
feature_treino_base, feature_rest, target_treino_base, target_rest = train_test_split(FEATURE, TARGET, test_size=0.5, random_state=42)
feature_valid_base, feature_test_meta, target_valid_base, target_test_meta = train_test_split(feature_rest, target_rest, test_size=0.4, random_state=42)

# %% [raw]
# feature_treino_base.... Conjunto de treino (50%) para os modelos base.
# target_treino_base......Conjunto de treino (50%) para os modelos base.
#
# feature_valid_base.....Conjunto de validação para os modelos base (30%), gerando features para o meta-modelo.
# target_valid_base......Conjunto de validação para os modelos base (30%), gerando features para o meta-modelo.
#
# feature_test_meta......Conjunto de teste para o meta-modelo (20%), para avaliar a performance do meta-modelo antes da predição final.
# target_test_meta.......Conjunto de teste para o meta-modelo (20%), para avaliar a performance do meta-modelo antes da predição final.

# %% [markdown]
# ## Modelos

# %% [markdown]
# ### Catboost

# %% [markdown]
# #### Iniciando Modelo

# %%
#### Iniciando o Modelo
modelo_c1 = CatBoostRegressor(
    iterations=1955,
    depth=5,
    learning_rate=0.00878515482955258,
    loss_function='RMSE',
    subsample= 0.7024609548921839,
    colsample_bylevel= 0.24231948861828084,
    l2_leaf_reg= 13.987621237707176,
    verbose=0
)

# %% [markdown]
# #### Treinando Modelo

# %%
modelo_c1.fit(feature_treino_base, target_treino_base)

# %% [markdown]
# #### Fazendo Previsão na Base (30%) // Gerando Feature Para Meta Modelo

# %%
feature_meta_c1 = modelo_c1.predict(feature_valid_base)
rmse_cat1 = np.sqrt(mean_squared_error(feature_meta_c1, target_valid_base))

# %% [markdown]
# ### XGBRegressor

# %% [markdown]
# #### Iniciando Modelo

# %%
modelo_x1 = XGBRegressor(n_estimators=2476,
                         learning_rate= 0.002713567157357714,
                         max_depth= 10,
                         subsample= 0.8412329047093903,
                         colsample_bytree= 0.8118853098655872,
                         gamma= 0.6454795935460096,
                         reg_alpha=0.023901381799989727,
                         reg_lambda= 3.298548751382269,
                         min_child_weight= 1,
                         random_state=42)

# %% [markdown]
# #### Treinando Modelo

# %%
modelo_x1.fit(feature_treino_base, target_treino_base)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8118853098655872, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.6454795935460096, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.002713567157357714,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2476, n_jobs=None,
#              num_parallel_tree=None, ...)

# %% [markdown]
# #### Fazendo Previsão na Base (30%) // Gerando Feature Para Meta Modelo

# %%
feature_meta_x1 = modelo_x1.predict(feature_valid_base)
rmse_x1 = np.sqrt(mean_squared_error(feature_meta_x1, target_valid_base))

# %% [markdown]
# ### LightGBM

# %% [markdown]
# #### Iniciando o Modelo

# %%
modelo_lgbm = LGBMRegressor(num_iterations= 1900,
                            learning_rate= 0.10809966608948998,
                            max_depth= 4,
                            num_leaves= 140,
                            min_data_in_leaf=11,
                            subsample= 0.9,
                            colsample_bytree= 0.7,
                            lambda_l1= 1.5229710918593735,
                            lambda_l2= 1.55538055462489,
                            min_gain_to_split= 0.11592155573870366,
                            random_state=69)

# %% [markdown]
# #### Treinando o Modelo

# %%
modelo_lgbm.fit(feature_treino_base, target_treino_base)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=0.11592155573870366, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.11592155573870366
# [LightGBM] [Warning] lambda_l2 is set=1.55538055462489, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.55538055462489
# [LightGBM] [Warning] lambda_l1 is set=1.5229710918593735, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5229710918593735
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=0.11592155573870366, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.11592155573870366
# [LightGBM] [Warning] lambda_l2 is set=1.55538055462489, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.55538055462489
# [LightGBM] [Warning] lambda_l1 is set=1.5229710918593735, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5229710918593735
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1640
# [LightGBM] [Info] Number of data points in the train set: 1095, number of used features: 12
# [LightGBM] [Info] Start training from score 0.749772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# LGBMRegressor(colsample_bytree=0.7, lambda_l1=1.5229710918593735,
#               lambda_l2=1.55538055462489, learning_rate=0.10809966608948998,
#               max_depth=4, min_data_in_leaf=11,
#               min_gain_to_split=0.11592155573870366, num_iterations=1900,
#               num_leaves=140, random_state=69, subsample=0.9)

# %% [markdown]
# #### Fazendo Previsão na Base (30%) // Gerando Feature Para Meta Modelo

# %%
feature_meta_lgbm = modelo_lgbm.predict(feature_valid_base)
rmse_lgbm = np.sqrt(mean_squared_error(feature_meta_lgbm, target_valid_base))
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=0.11592155573870366, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.11592155573870366
# [LightGBM] [Warning] lambda_l2 is set=1.55538055462489, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.55538055462489
# [LightGBM] [Warning] lambda_l1 is set=1.5229710918593735, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5229710918593735

# %% [markdown]
# ### LinearRegression

# %% [markdown]
# #### Iniciando Modelo

# %%
modelo_linear = LinearRegression()

# %% [markdown]
# #### Treinando Modelo

# %%
modelo_linear.fit(feature_treino_base, target_treino_base)
# Out:
# LinearRegression()

# %% [markdown]
# #### Fazendo Previsão na Base (30%) // Gerando Feature Para Meta Modelo

# %%
feature_meta_linear = modelo_linear.predict(feature_valid_base)
rmse_linear = np.sqrt(mean_squared_error(feature_meta_linear, target_valid_base))

# %% [markdown]
# ### AdaBoost

# %% [markdown]
# #### Inciando Modelo

# %%
modelo_ada = AdaBoostRegressor(n_estimators=117,
                               learning_rate = 0.009320996743568632, 
                               estimator=DecisionTreeRegressor(max_depth=4),
                               loss="square",
                               random_state=69)

# %% [markdown]
# #### Treinamento do Modelo

# %% [raw]
# import optuna
# import numpy as np
# from sklearn.ensemble import AdaBoostRegressor
# from sklearn.model_selection import cross_val_score
# from sklearn.tree import DecisionTreeRegressor
#
# # Definição da função objetivo para otimização
# def objective(trial):
#     params = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 1000),  # Número de árvores
#         'learning_rate': trial.suggest_float('learning_rate', 0.0001, 1.0, log=True),  # Taxa de aprendizado
#         'loss': trial.suggest_categorical('loss', ['linear', 'square', 'exponential']),  # Função de perda
#     }
#
#     # Base estimator (árvore de decisão)
#     estimator = DecisionTreeRegressor(
#         max_depth=trial.suggest_int('max_depth', 1, 10),  # Profundidade da árvore base
#     )
#
#     # Criar modelo AdaBoostRegressor com os hiperparâmetros sugeridos
#     model = AdaBoostRegressor(estimator=estimator, **params)
#
#     # Avaliação do modelo com validação cruzada
#     scores = cross_val_score(model, feature_treino_base, target_treino_base, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
#
#     return np.mean(scores)  # Média do erro quadrático negativo
#
# # Criando um estudo e rodando a otimização
# study = optuna.create_study(direction='maximize')  # Maximizar -MSE (equivalente a minimizar MSE)
# study.optimize(objective, n_trials=50)  # Ajuste o número de trials conforme necessário
#
# # Exibir os melhores hiperparâmetros encontrados
# print("Melhores hiperparâmetros:", study.best_params)

# %%
modelo_ada.fit(feature_treino_base, target_treino_base)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=4),
#                   learning_rate=0.009320996743568632, loss='square',
#                   n_estimators=117, random_state=69)

# %% [markdown]
# #### Fazendo Previsão na Base (30%) // Gerando Feature Para Meta Modelo

# %%
feature_meta_ada = modelo_ada.predict(feature_valid_base)
rmse_ada = np.sqrt(mean_squared_error(feature_meta_ada, target_valid_base))

# %% [markdown]
# ### Neural

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from sklearn.model_selection import train_test_split

# Função de erro RMSE corrigida
def rmse(y_true, y_pred):
    y_true = K.cast(y_true, dtype="float32")
    y_pred = K.cast(y_pred, dtype="float32")
    return K.sqrt(K.mean(K.square(y_true - y_pred)))

# Separar os dados em treino e validação
X_train, X_val, y_train, y_val = train_test_split(feature_treino_base, target_treino_base, test_size=0.2, random_state=42)

# Criar o modelo com os melhores hiperparâmetros
def criar_modelo():
    model = Sequential()
    
    # Primeira camada oculta
    model.add(Dense(160, activation="relu", input_shape=(X_train.shape[1],)))
    model.add(BatchNormalization())
    model.add(Dropout(0.49034062968575254))  # Dropout otimizado
    
    # Camada de saída
    model.add(Dense(1, activation="linear"))

    # Configurar otimizador com learning rate otimizado
    optimizer = Adam(learning_rate=0.0021515376914683355)
    
    model.compile(optimizer=optimizer, loss=rmse, metrics=["mae", rmse])
    return model

# Criar e treinar o modelo
modelo_otimizado = criar_modelo()
history = modelo_otimizado.fit(X_train, y_train, 
                               epochs=125, 
                               batch_size=16, 
                               validation_data=(X_val, y_val), 
                               verbose=1)

# Avaliação final
loss, mae, rmse_score = modelo_otimizado.evaluate(X_val, y_val, verbose=1)
print(f"RMSE final no conjunto de validação: {rmse_score}")
# Out:
# 2025-03-19 02:53:22.856762: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-19 02:53:24.183505: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/125
# 55/55 [==============================] - 1s 11ms/step - loss: 1.2010 - mae: 0.9361 - rmse: 1.1992 - val_loss: 0.3944 - val_mae: 0.3249 - val_rmse: 0.3945
# Epoch 2/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.8431 - mae: 0.6507 - rmse: 0.8433 - val_loss: 0.4754 - val_mae: 0.4231 - val_rmse: 0.4734
# Epoch 3/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6852 - mae: 0.5354 - rmse: 0.6849 - val_loss: 0.3683 - val_mae: 0.3268 - val_rmse: 0.3692
# Epoch 4/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.5220 - mae: 0.4114 - rmse: 0.5216 - val_loss: 0.4754 - val_mae: 0.4197 - val_rmse: 0.4784
# Epoch 5/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.4700 - mae: 0.3790 - rmse: 0.4693 - val_loss: 0.3962 - val_mae: 0.3690 - val_rmse: 0.3973
# Epoch 6/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.4191 - mae: 0.3357 - rmse: 0.4188 - val_loss: 0.3252 - val_mae: 0.2494 - val_rmse: 0.3282
# Epoch 7/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3816 - mae: 0.3015 - rmse: 0.3820 - val_loss: 0.3741 - val_mae: 0.3399 - val_rmse: 0.3762
# Epoch 8/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3764 - mae: 0.2965 - rmse: 0.3764 - val_loss: 0.3367 - val_mae: 0.2877 - val_rmse: 0.3383
# Epoch 9/125
# 55/55 [==============================] - 0s 4ms/step - loss: 0.3761 - mae: 0.2910 - rmse: 0.3765 - val_loss: 0.3837 - val_mae: 0.3474 - val_rmse: 0.3855
# Epoch 10/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3614 - mae: 0.2829 - rmse: 0.3612 - val_loss: 0.3531 - val_mae: 0.2867 - val_rmse: 0.3562
# Epoch 11/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3678 - mae: 0.2868 - rmse: 0.3675 - val_loss: 0.3110 - val_mae: 0.2208 - val_rmse: 0.3155
# Epoch 12/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3703 - mae: 0.2896 - rmse: 0.3696 - val_loss: 0.3067 - val_mae: 0.2179 - val_rmse: 0.3100
# Epoch 13/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3510 - mae: 0.2692 - rmse: 0.3518 - val_loss: 0.3049 - val_mae: 0.2125 - val_rmse: 0.3088
# Epoch 14/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3658 - mae: 0.2819 - rmse: 0.3662 - val_loss: 0.3167 - val_mae: 0.2140 - val_rmse: 0.3210
# Epoch 15/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3573 - mae: 0.2801 - rmse: 0.3575 - val_loss: 0.3377 - val_mae: 0.2366 - val_rmse: 0.3420
# Epoch 16/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3602 - mae: 0.2837 - rmse: 0.3598 - val_loss: 0.3522 - val_mae: 0.2460 - val_rmse: 0.3559
# Epoch 17/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3817 - mae: 0.2998 - rmse: 0.3816 - val_loss: 0.3790 - val_mae: 0.2763 - val_rmse: 0.3824
# Epoch 18/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3613 - mae: 0.2833 - rmse: 0.3616 - val_loss: 0.3521 - val_mae: 0.3123 - val_rmse: 0.3536
# Epoch 19/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3512 - mae: 0.2726 - rmse: 0.3513 - val_loss: 0.3352 - val_mae: 0.2860 - val_rmse: 0.3361
# Epoch 20/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3558 - mae: 0.2794 - rmse: 0.3559 - val_loss: 0.3248 - val_mae: 0.2329 - val_rmse: 0.3269
# Epoch 21/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3693 - mae: 0.2869 - rmse: 0.3692 - val_loss: 0.3161 - val_mae: 0.2182 - val_rmse: 0.3191
# Epoch 22/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3611 - mae: 0.2796 - rmse: 0.3604 - val_loss: 0.3036 - val_mae: 0.2065 - val_rmse: 0.3070
# Epoch 23/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3476 - mae: 0.2704 - rmse: 0.3478 - val_loss: 0.3031 - val_mae: 0.2204 - val_rmse: 0.3067
# Epoch 24/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3594 - mae: 0.2781 - rmse: 0.3590 - val_loss: 0.3182 - val_mae: 0.2504 - val_rmse: 0.3213
# Epoch 25/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3584 - mae: 0.2795 - rmse: 0.3583 - val_loss: 0.3360 - val_mae: 0.2649 - val_rmse: 0.3399
# Epoch 26/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3668 - mae: 0.2849 - rmse: 0.3670 - val_loss: 0.3182 - val_mae: 0.2431 - val_rmse: 0.3217
# Epoch 27/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3559 - mae: 0.2755 - rmse: 0.3558 - val_loss: 0.3122 - val_mae: 0.2098 - val_rmse: 0.3154
# Epoch 28/125
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3595 - mae: 0.2750 - rmse: 0.3595 - val_loss: 0.3224 - val_mae: 0.2207 - val_rmse: 0.3270
# Epoch 29/125
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3471 - mae: 0.2698 - rmse: 0.3473 - val_loss: 0.3350 - val_mae: 0.2338 - val_rmse: 0.3377
# Epoch 30/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3514 - mae: 0.2713 - rmse: 0.3511 - val_loss: 0.2984 - val_mae: 0.2049 - val_rmse: 0.3019
# Epoch 31/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3497 - mae: 0.2681 - rmse: 0.3495 - val_loss: 0.3076 - val_mae: 0.2115 - val_rmse: 0.3108
# Epoch 32/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3602 - mae: 0.2759 - rmse: 0.3608 - val_loss: 0.3042 - val_mae: 0.2304 - val_rmse: 0.3067
# Epoch 33/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3478 - mae: 0.2681 - rmse: 0.3475 - val_loss: 0.3119 - val_mae: 0.2177 - val_rmse: 0.3159
# Epoch 34/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3529 - mae: 0.2665 - rmse: 0.3531 - val_loss: 0.3439 - val_mae: 0.2248 - val_rmse: 0.3480
# Epoch 35/125
# 55/55 [==============================] - 0s 4ms/step - loss: 0.3503 - mae: 0.2663 - rmse: 0.3503 - val_loss: 0.3236 - val_mae: 0.2125 - val_rmse: 0.3275
# Epoch 36/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3352 - mae: 0.2548 - rmse: 0.3352 - val_loss: 0.3062 - val_mae: 0.2061 - val_rmse: 0.3100
# Epoch 37/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3386 - mae: 0.2584 - rmse: 0.3381 - val_loss: 0.3057 - val_mae: 0.2057 - val_rmse: 0.3096
# Epoch 38/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3509 - mae: 0.2659 - rmse: 0.3515 - val_loss: 0.3562 - val_mae: 0.2579 - val_rmse: 0.3603
# Epoch 39/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3558 - mae: 0.2734 - rmse: 0.3561 - val_loss: 0.3205 - val_mae: 0.2237 - val_rmse: 0.3249
# Epoch 40/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3490 - mae: 0.2672 - rmse: 0.3487 - val_loss: 0.2986 - val_mae: 0.2145 - val_rmse: 0.3014
# Epoch 41/125
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3484 - mae: 0.2705 - rmse: 0.3487 - val_loss: 0.3300 - val_mae: 0.2310 - val_rmse: 0.3330
# Epoch 42/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3497 - mae: 0.2686 - rmse: 0.3497 - val_loss: 0.3138 - val_mae: 0.2146 - val_rmse: 0.3183
# Epoch 43/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3460 - mae: 0.2650 - rmse: 0.3462 - val_loss: 0.3110 - val_mae: 0.2127 - val_rmse: 0.3147
# Epoch 44/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3522 - mae: 0.2688 - rmse: 0.3522 - val_loss: 0.2999 - val_mae: 0.2068 - val_rmse: 0.3033
# Epoch 45/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3438 - mae: 0.2622 - rmse: 0.3434 - val_loss: 0.3178 - val_mae: 0.2188 - val_rmse: 0.3215
# Epoch 46/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3444 - mae: 0.2643 - rmse: 0.3438 - val_loss: 0.3231 - val_mae: 0.2270 - val_rmse: 0.3267
# Epoch 47/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3506 - mae: 0.2653 - rmse: 0.3510 - val_loss: 0.3090 - val_mae: 0.2239 - val_rmse: 0.3133
# Epoch 48/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3539 - mae: 0.2705 - rmse: 0.3538 - val_loss: 0.3121 - val_mae: 0.2144 - val_rmse: 0.3154
# Epoch 49/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3502 - mae: 0.2695 - rmse: 0.3494 - val_loss: 0.3049 - val_mae: 0.2063 - val_rmse: 0.3086
# Epoch 50/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3458 - mae: 0.2633 - rmse: 0.3458 - val_loss: 0.3265 - val_mae: 0.2274 - val_rmse: 0.3307
# Epoch 51/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3397 - mae: 0.2592 - rmse: 0.3396 - val_loss: 0.3312 - val_mae: 0.2228 - val_rmse: 0.3354
# Epoch 52/125
# 55/55 [==============================] - 0s 4ms/step - loss: 0.3466 - mae: 0.2636 - rmse: 0.3466 - val_loss: 0.3450 - val_mae: 0.2391 - val_rmse: 0.3492
# Epoch 53/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3415 - mae: 0.2596 - rmse: 0.3410 - val_loss: 0.3406 - val_mae: 0.2401 - val_rmse: 0.3445
# Epoch 54/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3360 - mae: 0.2507 - rmse: 0.3361 - val_loss: 0.3192 - val_mae: 0.2177 - val_rmse: 0.3233
# Epoch 55/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3442 - mae: 0.2678 - rmse: 0.3437 - val_loss: 0.3248 - val_mae: 0.2242 - val_rmse: 0.3291
# Epoch 56/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3566 - mae: 0.2715 - rmse: 0.3561 - val_loss: 0.3282 - val_mae: 0.2245 - val_rmse: 0.3316
# Epoch 57/125
# 55/55 [==============================] - 0s 6ms/step - loss: 0.3424 - mae: 0.2612 - rmse: 0.3430 - val_loss: 0.3200 - val_mae: 0.2179 - val_rmse: 0.3245
# Epoch 58/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3383 - mae: 0.2529 - rmse: 0.3384 - val_loss: 0.3362 - val_mae: 0.2321 - val_rmse: 0.3404
# Epoch 59/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3529 - mae: 0.2720 - rmse: 0.3530 - val_loss: 0.3260 - val_mae: 0.2228 - val_rmse: 0.3299
# Epoch 60/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3361 - mae: 0.2542 - rmse: 0.3363 - val_loss: 0.3483 - val_mae: 0.2452 - val_rmse: 0.3514
# Epoch 61/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3394 - mae: 0.2572 - rmse: 0.3395 - val_loss: 0.3174 - val_mae: 0.2202 - val_rmse: 0.3217
# Epoch 62/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3479 - mae: 0.2617 - rmse: 0.3478 - val_loss: 0.3073 - val_mae: 0.2126 - val_rmse: 0.3102
# Epoch 63/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3387 - mae: 0.2592 - rmse: 0.3389 - val_loss: 0.3018 - val_mae: 0.2048 - val_rmse: 0.3055
# Epoch 64/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3424 - mae: 0.2567 - rmse: 0.3422 - val_loss: 0.3196 - val_mae: 0.2185 - val_rmse: 0.3241
# Epoch 65/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3501 - mae: 0.2642 - rmse: 0.3503 - val_loss: 0.3231 - val_mae: 0.2167 - val_rmse: 0.3270
# Epoch 66/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3355 - mae: 0.2578 - rmse: 0.3350 - val_loss: 0.3530 - val_mae: 0.2557 - val_rmse: 0.3574
# Epoch 67/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3442 - mae: 0.2645 - rmse: 0.3440 - val_loss: 0.3388 - val_mae: 0.2382 - val_rmse: 0.3437
# Epoch 68/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3386 - mae: 0.2559 - rmse: 0.3386 - val_loss: 0.3077 - val_mae: 0.2089 - val_rmse: 0.3111
# Epoch 69/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3409 - mae: 0.2595 - rmse: 0.3408 - val_loss: 0.3242 - val_mae: 0.2269 - val_rmse: 0.3276
# Epoch 70/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3361 - mae: 0.2566 - rmse: 0.3365 - val_loss: 0.3045 - val_mae: 0.2074 - val_rmse: 0.3081
# Epoch 71/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3474 - mae: 0.2649 - rmse: 0.3472 - val_loss: 0.3067 - val_mae: 0.2268 - val_rmse: 0.3105
# Epoch 72/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3414 - mae: 0.2573 - rmse: 0.3411 - val_loss: 0.3048 - val_mae: 0.2086 - val_rmse: 0.3090
# Epoch 73/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3392 - mae: 0.2589 - rmse: 0.3390 - val_loss: 0.3109 - val_mae: 0.2097 - val_rmse: 0.3146
# Epoch 74/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3379 - mae: 0.2590 - rmse: 0.3378 - val_loss: 0.3187 - val_mae: 0.2232 - val_rmse: 0.3225
# Epoch 75/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3451 - mae: 0.2649 - rmse: 0.3451 - val_loss: 0.3193 - val_mae: 0.2322 - val_rmse: 0.3238
# Epoch 76/125
# 55/55 [==============================] - 1s 14ms/step - loss: 0.3348 - mae: 0.2577 - rmse: 0.3340 - val_loss: 0.3287 - val_mae: 0.2392 - val_rmse: 0.3337
# Epoch 77/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3466 - mae: 0.2639 - rmse: 0.3473 - val_loss: 0.3203 - val_mae: 0.2128 - val_rmse: 0.3244
# Epoch 78/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3403 - mae: 0.2544 - rmse: 0.3402 - val_loss: 0.3372 - val_mae: 0.2356 - val_rmse: 0.3407
# Epoch 79/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3392 - mae: 0.2554 - rmse: 0.3397 - val_loss: 0.3345 - val_mae: 0.2317 - val_rmse: 0.3389
# Epoch 80/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3388 - mae: 0.2550 - rmse: 0.3391 - val_loss: 0.3062 - val_mae: 0.2135 - val_rmse: 0.3094
# Epoch 81/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3392 - mae: 0.2588 - rmse: 0.3398 - val_loss: 0.3042 - val_mae: 0.2258 - val_rmse: 0.3077
# Epoch 82/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3477 - mae: 0.2615 - rmse: 0.3475 - val_loss: 0.3031 - val_mae: 0.2045 - val_rmse: 0.3070
# Epoch 83/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3373 - mae: 0.2546 - rmse: 0.3380 - val_loss: 0.3012 - val_mae: 0.2147 - val_rmse: 0.3045
# Epoch 84/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3401 - mae: 0.2615 - rmse: 0.3398 - val_loss: 0.3111 - val_mae: 0.2083 - val_rmse: 0.3151
# Epoch 85/125
# 55/55 [==============================] - 1s 12ms/step - loss: 0.3323 - mae: 0.2538 - rmse: 0.3321 - val_loss: 0.3302 - val_mae: 0.2361 - val_rmse: 0.3339
# Epoch 86/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3373 - mae: 0.2510 - rmse: 0.3367 - val_loss: 0.3043 - val_mae: 0.2051 - val_rmse: 0.3082
# Epoch 87/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3327 - mae: 0.2515 - rmse: 0.3325 - val_loss: 0.3401 - val_mae: 0.2351 - val_rmse: 0.3442
# Epoch 88/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3394 - mae: 0.2573 - rmse: 0.3389 - val_loss: 0.3449 - val_mae: 0.2447 - val_rmse: 0.3488
# Epoch 89/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3394 - mae: 0.2583 - rmse: 0.3399 - val_loss: 0.3141 - val_mae: 0.2124 - val_rmse: 0.3178
# Epoch 90/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3437 - mae: 0.2604 - rmse: 0.3437 - val_loss: 0.3070 - val_mae: 0.2211 - val_rmse: 0.3101
# Epoch 91/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3437 - mae: 0.2585 - rmse: 0.3443 - val_loss: 0.2995 - val_mae: 0.2037 - val_rmse: 0.3032
# Epoch 92/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3393 - mae: 0.2548 - rmse: 0.3398 - val_loss: 0.3177 - val_mae: 0.2146 - val_rmse: 0.3219
# Epoch 93/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3424 - mae: 0.2627 - rmse: 0.3429 - val_loss: 0.3056 - val_mae: 0.2169 - val_rmse: 0.3094
# Epoch 94/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3339 - mae: 0.2496 - rmse: 0.3346 - val_loss: 0.2982 - val_mae: 0.2100 - val_rmse: 0.3018
# Epoch 95/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3249 - mae: 0.2396 - rmse: 0.3252 - val_loss: 0.3089 - val_mae: 0.2112 - val_rmse: 0.3121
# Epoch 96/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3330 - mae: 0.2482 - rmse: 0.3328 - val_loss: 0.3044 - val_mae: 0.2053 - val_rmse: 0.3081
# Epoch 97/125
# 55/55 [==============================] - 1s 14ms/step - loss: 0.3338 - mae: 0.2495 - rmse: 0.3331 - val_loss: 0.3219 - val_mae: 0.2129 - val_rmse: 0.3260
# Epoch 98/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3433 - mae: 0.2581 - rmse: 0.3442 - val_loss: 0.3042 - val_mae: 0.2096 - val_rmse: 0.3083
# Epoch 99/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3390 - mae: 0.2546 - rmse: 0.3389 - val_loss: 0.3005 - val_mae: 0.2087 - val_rmse: 0.3043
# Epoch 100/125
# 55/55 [==============================] - 1s 12ms/step - loss: 0.3419 - mae: 0.2619 - rmse: 0.3413 - val_loss: 0.3013 - val_mae: 0.2077 - val_rmse: 0.3048
# Epoch 101/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3282 - mae: 0.2449 - rmse: 0.3277 - val_loss: 0.3101 - val_mae: 0.2156 - val_rmse: 0.3134
# Epoch 102/125
# 55/55 [==============================] - 1s 15ms/step - loss: 0.3390 - mae: 0.2553 - rmse: 0.3384 - val_loss: 0.3130 - val_mae: 0.2105 - val_rmse: 0.3166
# Epoch 103/125
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3385 - mae: 0.2587 - rmse: 0.3389 - val_loss: 0.3094 - val_mae: 0.2221 - val_rmse: 0.3132
# Epoch 104/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3421 - mae: 0.2608 - rmse: 0.3422 - val_loss: 0.2998 - val_mae: 0.2204 - val_rmse: 0.3028
# Epoch 105/125
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3355 - mae: 0.2499 - rmse: 0.3355 - val_loss: 0.2999 - val_mae: 0.2047 - val_rmse: 0.3035
# Epoch 106/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3390 - mae: 0.2531 - rmse: 0.3388 - val_loss: 0.2993 - val_mae: 0.2064 - val_rmse: 0.3028
# Epoch 107/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3332 - mae: 0.2498 - rmse: 0.3335 - val_loss: 0.3012 - val_mae: 0.2092 - val_rmse: 0.3050
# Epoch 108/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3400 - mae: 0.2585 - rmse: 0.3399 - val_loss: 0.3022 - val_mae: 0.2242 - val_rmse: 0.3055
# Epoch 109/125
# 55/55 [==============================] - 1s 16ms/step - loss: 0.3309 - mae: 0.2456 - rmse: 0.3307 - val_loss: 0.3268 - val_mae: 0.2178 - val_rmse: 0.3304
# Epoch 110/125
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3331 - mae: 0.2431 - rmse: 0.3331 - val_loss: 0.3003 - val_mae: 0.2119 - val_rmse: 0.3043
# Epoch 111/125
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3302 - mae: 0.2481 - rmse: 0.3301 - val_loss: 0.3098 - val_mae: 0.2386 - val_rmse: 0.3130
# Epoch 112/125
# 55/55 [==============================] - 1s 12ms/step - loss: 0.3395 - mae: 0.2556 - rmse: 0.3398 - val_loss: 0.3059 - val_mae: 0.2080 - val_rmse: 0.3096
# Epoch 113/125
# 55/55 [==============================] - 1s 18ms/step - loss: 0.3329 - mae: 0.2496 - rmse: 0.3323 - val_loss: 0.3285 - val_mae: 0.2222 - val_rmse: 0.3324
# Epoch 114/125
# 55/55 [==============================] - 1s 13ms/step - loss: 0.3348 - mae: 0.2477 - rmse: 0.3345 - val_loss: 0.3131 - val_mae: 0.2085 - val_rmse: 0.3171
# Epoch 115/125
# 55/55 [==============================] - 0s 7ms/step - loss: 0.3237 - mae: 0.2399 - rmse: 0.3246 - val_loss: 0.2967 - val_mae: 0.2087 - val_rmse: 0.3002
# Epoch 116/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3373 - mae: 0.2513 - rmse: 0.3372 - val_loss: 0.3105 - val_mae: 0.2091 - val_rmse: 0.3145
# Epoch 117/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3371 - mae: 0.2509 - rmse: 0.3373 - val_loss: 0.3082 - val_mae: 0.2287 - val_rmse: 0.3123
# Epoch 118/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3340 - mae: 0.2513 - rmse: 0.3341 - val_loss: 0.3059 - val_mae: 0.2087 - val_rmse: 0.3100
# Epoch 119/125
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3392 - mae: 0.2522 - rmse: 0.3387 - val_loss: 0.3348 - val_mae: 0.2326 - val_rmse: 0.3389
# Epoch 120/125
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3295 - mae: 0.2428 - rmse: 0.3289 - val_loss: 0.3105 - val_mae: 0.2150 - val_rmse: 0.3146
# Epoch 121/125
# 55/55 [==============================] - 1s 10ms/step - loss: 0.3329 - mae: 0.2499 - rmse: 0.3328 - val_loss: 0.3298 - val_mae: 0.2228 - val_rmse: 0.3339
# Epoch 122/125
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3307 - mae: 0.2462 - rmse: 0.3310 - val_loss: 0.3202 - val_mae: 0.2129 - val_rmse: 0.3243
# Epoch 123/125
# 55/55 [==============================] - 1s 11ms/step - loss: 0.3413 - mae: 0.2562 - rmse: 0.3408 - val_loss: 0.3576 - val_mae: 0.2480 - val_rmse: 0.3617
# Epoch 124/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3357 - mae: 0.2488 - rmse: 0.3362 - val_loss: 0.3178 - val_mae: 0.2116 - val_rmse: 0.3215
# Epoch 125/125
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3362 - mae: 0.2550 - rmse: 0.3361 - val_loss: 0.3214 - val_mae: 0.2172 - val_rmse: 0.3252
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3223 - mae: 0.2172 - rmse: 0.3261
# RMSE final no conjunto de validação: 0.32609623670578003

# %% [raw]
# import optuna
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
# from tensorflow.keras.optimizers import Adam
# import keras.backend as K
# from sklearn.model_selection import train_test_split
#
# # Definir função de erro RMSE corrigida
# def rmse(y_true, y_pred):
#     y_true = K.cast(y_true, dtype="float32")
#     y_pred = K.cast(y_pred, dtype="float32")
#     return K.sqrt(K.mean(K.square(y_true - y_pred)))
#
# # Dados
# X_train, X_val, y_train, y_val = train_test_split(feature_treino_base, target_treino_base, test_size=0.2, random_state=42)
#
# # Função para criar o modelo com hiperparâmetros variáveis
# def criar_modelo(trial, input_shape):
#     model = Sequential()
#
#     # Número de camadas ocultas (optimizável)
#     num_layers = trial.suggest_int("num_layers", 1, 3)
#
#     for i in range(num_layers):
#         units = trial.suggest_int(f"units_l{i}", 32, 256, step=32)
#         activation = trial.suggest_categorical("activation", ["relu", "tanh"])
#         model.add(Dense(units, activation=activation))
#         model.add(BatchNormalization())
#
#         dropout_rate = trial.suggest_float(f"dropout_l{i}", 0.1, 0.5)
#         model.add(Dropout(dropout_rate))
#
#     model.add(Dense(1, activation="linear"))
#
#     # Otimização do learning rate
#     learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-2, log=True)
#     optimizer = Adam(learning_rate=learning_rate)
#
#     model.compile(optimizer=optimizer, loss=rmse, metrics=["mae", rmse])
#     return model
#
# # Função objetivo para Optuna
# def objective(trial):
#     model = criar_modelo(trial, X_train.shape[1])
#
#     batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
#
#     history = model.fit(X_train, y_train,
#                         epochs=30,
#                         batch_size=batch_size,
#                         validation_data=(X_val, y_val),
#                         verbose=0)
#
#     val_loss = min(history.history["val_loss"])  # Pega o menor RMSE
#     return val_loss
#
# # Criando e rodando o estudo do Optuna
# study = optuna.create_study(direction="minimize")
# study.optimize(objective, n_trials=30)
#
# # Exibir melhores hiperparâmetros
# print("Melhores hiperparâmetros encontrados:", study.best_params)

# %%
feature_meta_neural = modelo_otimizado.predict(feature_valid_base)
rmse_neural = np.sqrt(mean_squared_error(feature_meta_neural, target_valid_base))
# Out:
# 21/21 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Teste dos Modelos

# %%
print(f"CatBoost RMSE ...........{rmse_cat1}")
print(f"XGBRegressor RMSE .......{rmse_x1}")
print(f"LightLGBM RMSE ..........{rmse_lgbm}") 
print(f"LinearRegression RMSE ...{rmse_linear}") 
print(f"AdaBoost RMSE............{rmse_ada}")
print(f"Neural RMSE:............ {rmse_neural}")
# Out:
# CatBoost RMSE ...........0.3290486490320497
# XGBRegressor RMSE .......0.3294914833518092
# LightLGBM RMSE ..........0.3265194255839313
# LinearRegression RMSE ...0.3311290087954679
# AdaBoost RMSE............0.3325683449975139
# Neural RMSE:............ 0.3600888625712664

# %% [markdown]
# ## Meta-Modelo

# %% [markdown]
# #### Feature para Treino do Meta-Modelo

# %%
feature_meta_unificada = pd.DataFrame()

feature_meta_c1 = pd.Series(feature_meta_c1)
feature_meta_x1 = pd.Series(feature_meta_x1)
feature_meta_lgbm = pd.Series(feature_meta_lgbm)
feature_meta_linear = pd.Series(feature_meta_linear)
feature_meta_ada = pd.Series(feature_meta_ada)

feature_meta_unificada['CatBoost'] = feature_meta_c1
feature_meta_unificada['XGBRegressor'] = feature_meta_x1
feature_meta_unificada['LightGBM'] = feature_meta_lgbm
feature_meta_unificada['Linear'] = feature_meta_linear
feature_meta_unificada['Ada'] = feature_meta_ada
feature_meta_unificada['Neural'] = feature_meta_neural

##target_valid_base

# %% [markdown]
# #### Feature para Previsão Final

# %%
feature_final1 = modelo_c1.predict(data_teste)
feature_final2 = modelo_x1.predict(data_teste)
feature_final3 = modelo_lgbm.predict(data_teste)
feature_final4 = modelo_linear.predict(data_teste)
feature_final5 = modelo_ada.predict(data_teste)
feature_final6 = modelo_otimizado.predict(data_teste)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] min_gain_to_split is set=0.11592155573870366, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.11592155573870366
# [LightGBM] [Warning] lambda_l2 is set=1.55538055462489, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.55538055462489
# [LightGBM] [Warning] lambda_l1 is set=1.5229710918593735, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5229710918593735
# 23/23 [==============================] - 0s 3ms/step

# %%
feature_meta_unificada_final = pd.DataFrame({
    'CatBoost': feature_final1,
    'XGBRegressor': feature_final2,
    'LightGBM': feature_final3,
    'Linear': feature_final4,
    'Ada': feature_final5,
    'Neural': feature_final6.ravel()
})

# %% [markdown]
# #### Criação do Meta-Modelo

# %%
meta_modelo = CatBoostRegressor(
    iterations=1973,
    depth=4,
    learning_rate=0.0031470236892576554,
    loss_function='RMSE',
    subsample= 0.8163554441989388,
    colsample_bylevel= 0.4701500303061581,
    l2_leaf_reg= 19.72460023484443,
    verbose=0
)

meta_modelo.fit(feature_meta_unificada, target_valid_base)

# %% [markdown]
# #### Previsão Final e CSV

# %%
previsao_final = meta_modelo.predict(feature_meta_unificada_final)

output = pd.DataFrame({'id': data_teste['id'], 'rainfall': previsao_final})
output.to_csv('testeeee.csv', index=False)

# %% [raw]
# import optuna
# from catboost import CatBoostRegressor
# import numpy as np
# from sklearn.model_selection import cross_val_score
#
# # Definição da função objetivo para otimização
# def objective(trial):
#     params = {
#         'iterations': trial.suggest_int('iterations', 100, 3000),
#         'learning_rate': trial.suggest_float('learning_rate', 0.00001, 1.0, log=True),
#         'depth': trial.suggest_int('depth', 2, 8),
#         'subsample': trial.suggest_float('subsample', 0.2, 1.0),
#         'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.2, 1.0),
#         'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.0, 20.0),
#         'random_seed': 42,
#         'verbose': 0
#     }
#
#
#
#     # Criar modelo CatBoostRegressor com os hiperparâmetros sugeridos
#     model = CatBoostRegressor(**params)
#
#     # Avaliação do modelo com validação cruzada
#     scores = cross_val_score(model, feature_meta_unificada, target_valid_base, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
#
#     return np.mean(scores)  # Média do erro quadrático negativo
#
# # Criando um estudo e rodando a otimização
# study = optuna.create_study(direction='maximize')  # Maximizar -MSE (equivalente a minimizar MSE)
# study.optimize(objective, n_trials=50)  # Ajuste o número de trials
#
# # Exibir os melhores hiperparâmetros encontrados
# print("Melhores hiperparâmetros:", study.best_params)

# %%
Melhores hiperparâmetros: {'iterations': 1973, 'learning_rate': 0.0031470236892576554, 'depth': 4, 'subsample': 0.8163554441989388, 'colsample_bylevel': 0.4701500303061581, 'l2_leaf_reg': 19.72460023484443}
